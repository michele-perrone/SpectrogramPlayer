# %% [markdown]
# <a href="https://colab.research.google.com/github/michele-perrone/SpectrogramPlayer/blob/main/Source/GstPEAQ_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**GstPEAQ testing**
# In this notebook, we use GstPEAQ to test the results obtained by the various techniques.
# The audio clips must be available as `.wav` audio files.
# Please note that GstPEAQ comes only as Gst plugin or as a command-line utility. We will use it as the former by creating command strings to be executed on the local terminal. Therefore, you must install GstPEAQ on you local machine in order to run this notebook.
# **Important!** Make sure you set the correct `project_path`

# %%
# Import necessary libraries

import numpy as np
import pickle
import librosa
import pathlib
from pathlib import Path
import os
import subprocess
import soundfile as sf
import pickle as pkl

# %%
# Set the project path

project_path = pathlib.Path('/home/michele/Projects/SpectrogramPlayer')
# %cd $project_path
# Out:
# /home/michele/Projects/SpectrogramPlayer

# %%
# Test if GstPEAQ is available

output = subprocess.check_output("peaq --help", shell=True)
print(output.decode())
# Out:
# Usage:
#   peaq [OPTION?] REFFILE TESTFILE
#
# peaq computes the Objective Difference Grade based on ITU-R BS.1367-1 (but it
# does not meet its conformance requirements).
#
# Help Options:
#   -h, --help                        Show help options
#   --help-all                        Show all help options
#   --help-gst                        Show GStreamer Options
#
# Application Options:
#   --version                         print version information
#   --advanced                        use advanced version
#   --basic                           use basic version (default)
#
# Report bugs to: <martin.holters@hsu-hh.de>
# GstPEAQ home page: <http://ant.hsu-hh.de/gstpeaq>

# %%
# Make a list of the paths where the different genres reside

speech_results_path = pathlib.Path('./Results/Speech')
speech_results_path = pathlib.Path(os.path.join(project_path, speech_results_path))

music_results_path = pathlib.Path('./Results/Music')
music_results_path = pathlib.Path(os.path.join(project_path, music_results_path))

urban_results_path = pathlib.Path('./Results/Urban')
urban_results_path = pathlib.Path(os.path.join(project_path, urban_results_path))

results_path_list = {'speech': speech_results_path, 
                     'music': music_results_path, 
                     'urban': urban_results_path}

# %%
num_of_test_files = 20

# For each genre... (music, speech, urban)
for current_genre in results_path_list: ## <---- FOR EACH GENRE BEGINS
  
  # Print the genre we're dealing with
  print("Currently processing: %s" %(current_genre))

  # Initialize an empty dictionary for PEAQ results
  peaq = {
      'no_phase': np.empty((num_of_test_files, 1), dtype=float),
      'griffin_lim': np.empty((num_of_test_files, 1), dtype=float),
      'deepgl_biased_70': np.empty((num_of_test_files, 1), dtype=float),
      'deepgl_unbiased_70': np.empty((num_of_test_files, 1), dtype=float),
      'melgan': np.empty((num_of_test_files, 1), dtype=float),
      'hifigan': np.empty((num_of_test_files, 1), dtype=float),
      'uniglow': np.empty((num_of_test_files, 1), dtype=float),
      'squeezewave': np.empty((num_of_test_files, 1), dtype=float),
      'univnet': np.empty((num_of_test_files, 1), dtype=float),
  }

  # Import the pickle dictionary for this genre.
  # We're going to append to it the testing results of GSTPeaq (the `peaq` dictionary allocated above!)
  in_file = open(os.path.join(results_path_list[current_genre], 'metrics_' + current_genre + '.pkl'), "rb")
  metrics = pickle.load(in_file)
  in_file.close()

  # For each folder in the results path...
  # (each folder corresponds to a technique)
  for current_dir in results_path_list[current_genre].iterdir(): ## <---- FOR EACH TECHNIQUE BEGINS
    
    # ... check if it's a directory and that it's not the "signals_* folder"
    if current_dir.is_dir() and not str(current_dir.name).startswith("signals_"):
      current_technique = current_dir.name.replace('_' + current_genre,'')
      print("Current technique: %s" %(current_technique))
      print("Current folder: %s" %(current_dir))
      
      # Compare the reference signals with the reconstructed signals
      for current_rcstr_signal_path in sorted(current_dir.iterdir()): # Ordered in ascending order (same order as ref. signals!!)
        # For each reconstructed signal that we found, we go and look for the
        # reference signal in the "signals_*" folder.

        # Reference signal path:
        current_ref_signal_path = str(current_rcstr_signal_path).replace(str(current_technique), 'signals')
        print("Reference signal path: %s" %(current_ref_signal_path))
        # Reconstructed signal path:
        print("Reconstructed signal path: %s" %(current_rcstr_signal_path))
        
        # Compose the command string, used to invoke peaq from the console
        command = "peaq --basic %s %s" %(current_ref_signal_path, current_rcstr_signal_path)
        # Call peaq and store the output
        current_peaq_output = subprocess.check_output(command, shell=True).decode()
        # We have to un-format the output and keep only the Objective Difference Grade 
        current_peaq_output = subprocess.check_output(command, shell=True).decode().partition('\n')
        objective_difference_grade = float(current_peaq_output[0] # Keep only the first line
                                          .replace('Objective Difference Grade: ', '') # Remove the description
                                          ) # Convert the string to float [1,5]
        distortion_index = float(current_peaq_output[2] # Keep only the second line
                            .replace('Distortion Index: ', '') # Remove the description
                            )# Convert the string to float                                
        print("Objective difference grade: %.3f. Distortion index: %.3f\n" %(objective_difference_grade, distortion_index))
        # Store the ODG in the dictionary
        idx = int(current_rcstr_signal_path.name.replace('.wav', ''))
        peaq[current_technique][idx] = objective_difference_grade
        
    print("\n") ## <---- FOR EACH TECHNIQUE ENDS
  
  print("\n") ## <---- FOR EACH GENRE ENDS
  
  # Append the PEAQ results for this genre to the existing dictionary and save it to file
  metrics = {'RMSE': metrics['RMSE'],
            'NRMSE': metrics['NRMSE'],
            'PESQ': metrics['PESQ'],
            'MOSNET': metrics['MOSNET'],
            'RMSE_phase': metrics['RMSE_phase'],
            'NRMSE_phase': metrics['NRMSE_phase'],
            'PEAQ': peaq
            }

  out_file = open(os.path.join(results_path_list[current_genre], 'metrics_' + current_genre + '.pkl'), "wb")
  pickle.dump(metrics, out_file)
  out_file.close()
# Out:
# Currently processing: speech
# Current technique: no_phase
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/0.wav
# Objective difference grade: -3.902. Distortion index: -3.965
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/1.wav
# Objective difference grade: -3.896. Distortion index: -3.888
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/10.wav
# Objective difference grade: -3.898. Distortion index: -3.916
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/11.wav
# Objective difference grade: -3.893. Distortion index: -3.851
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/12.wav
# Objective difference grade: -3.886. Distortion index: -3.779
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/13.wav
# Objective difference grade: -3.898. Distortion index: -3.910
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/14.wav
# Objective difference grade: -3.899. Distortion index: -3.932
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/15.wav
# Objective difference grade: -3.893. Distortion index: -3.861
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/16.wav
# Objective difference grade: -3.891. Distortion index: -3.836
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/17.wav
# Objective difference grade: -3.897. Distortion index: -3.903
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/18.wav
# Objective difference grade: -3.897. Distortion index: -3.906
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/19.wav
# Objective difference grade: -3.901. Distortion index: -3.957
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/2.wav
# Objective difference grade: -3.896. Distortion index: -3.887
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/3.wav
# Objective difference grade: -3.897. Distortion index: -3.908
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/4.wav
# Objective difference grade: -3.900. Distortion index: -3.938
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/5.wav
# Objective difference grade: -3.888. Distortion index: -3.793
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/6.wav
# Objective difference grade: -3.886. Distortion index: -3.781
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/7.wav
# Objective difference grade: -3.897. Distortion index: -3.908
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/8.wav
# Objective difference grade: -3.901. Distortion index: -3.951
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/no_phase_speech/9.wav
# Objective difference grade: -3.897. Distortion index: -3.907
#
#
#
#
#
# Current technique: griffin_lim
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/0.wav
# Objective difference grade: -3.183. Distortion index: -1.452
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/1.wav
# Objective difference grade: -3.515. Distortion index: -2.084
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/10.wav
# Objective difference grade: -3.147. Distortion index: -1.397
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/11.wav
# Objective difference grade: -3.413. Distortion index: -1.857
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/12.wav
# Objective difference grade: -3.100. Distortion index: -1.327
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/13.wav
# Objective difference grade: -3.277. Distortion index: -1.604
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/14.wav
# Objective difference grade: -3.310. Distortion index: -1.661
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/15.wav
# Objective difference grade: -3.598. Distortion index: -2.302
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/16.wav
# Objective difference grade: -3.277. Distortion index: -1.604
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/17.wav
# Objective difference grade: -3.482. Distortion index: -2.006
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/18.wav
# Objective difference grade: -3.137. Distortion index: -1.382
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/19.wav
# Objective difference grade: -3.579. Distortion index: -2.247
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/2.wav
# Objective difference grade: -3.560. Distortion index: -2.198
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/3.wav
# Objective difference grade: -3.456. Distortion index: -1.949
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/4.wav
# Objective difference grade: -3.488. Distortion index: -2.020
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/5.wav
# Objective difference grade: -3.401. Distortion index: -1.832
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/6.wav
# Objective difference grade: -3.510. Distortion index: -2.071
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/7.wav
# Objective difference grade: -3.235. Distortion index: -1.534
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/8.wav
# Objective difference grade: -3.618. Distortion index: -2.360
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/griffin_lim_speech/9.wav
# Objective difference grade: -3.362. Distortion index: -1.758
#
#
#
#
#
#
#
#
#
# Current technique: melgan
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/0.wav
# Objective difference grade: -3.913. Distortion index: -4.119
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/1.wav
# Objective difference grade: -3.911. Distortion index: -4.091
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/10.wav
# Objective difference grade: -3.912. Distortion index: -4.113
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/11.wav
# Objective difference grade: -3.912. Distortion index: -4.113
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/12.wav
# Objective difference grade: -3.912. Distortion index: -4.103
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/13.wav
# Objective difference grade: -3.913. Distortion index: -4.116
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/14.wav
# Objective difference grade: -3.913. Distortion index: -4.116
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/15.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/16.wav
# Objective difference grade: -3.912. Distortion index: -4.109
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/17.wav
# Objective difference grade: -3.912. Distortion index: -4.112
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/18.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/19.wav
# Objective difference grade: -3.913. Distortion index: -4.116
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/2.wav
# Objective difference grade: -3.912. Distortion index: -4.101
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/3.wav
# Objective difference grade: -3.912. Distortion index: -4.110
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/4.wav
# Objective difference grade: -3.913. Distortion index: -4.119
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/5.wav
# Objective difference grade: -3.911. Distortion index: -4.099
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/6.wav
# Objective difference grade: -3.911. Distortion index: -4.095
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/7.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/8.wav
# Objective difference grade: -3.913. Distortion index: -4.116
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/melgan_speech/9.wav
# Objective difference grade: -3.912. Distortion index: -4.101
#
#
#
# Current technique: univnet
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/0.wav
# Objective difference grade: -3.913. Distortion index: -4.120
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/1.wav
# Objective difference grade: -3.911. Distortion index: -4.099
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/10.wav
# Objective difference grade: -3.912. Distortion index: -4.111
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/11.wav
# Objective difference grade: -3.912. Distortion index: -4.112
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/12.wav
# Objective difference grade: -3.912. Distortion index: -4.102
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/13.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/14.wav
# Objective difference grade: -3.913. Distortion index: -4.118
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/15.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/16.wav
# Objective difference grade: -3.912. Distortion index: -4.111
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/17.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/18.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/19.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/2.wav
# Objective difference grade: -3.912. Distortion index: -4.108
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/3.wav
# Objective difference grade: -3.912. Distortion index: -4.112
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/4.wav
# Objective difference grade: -3.913. Distortion index: -4.119
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/5.wav
# Objective difference grade: -3.912. Distortion index: -4.100
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/6.wav
# Objective difference grade: -3.912. Distortion index: -4.101
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/7.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/8.wav
# Objective difference grade: -3.913. Distortion index: -4.118
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/univnet_speech/9.wav
# Objective difference grade: -3.912. Distortion index: -4.103
#
#
#
# Current technique: deepgl_unbiased_70
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/0.wav
# Objective difference grade: -3.376. Distortion index: -1.784
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/1.wav
# Objective difference grade: -3.380. Distortion index: -1.792
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/10.wav
# Objective difference grade: -3.327. Distortion index: -1.693
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/11.wav
# Objective difference grade: -3.382. Distortion index: -1.795
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/12.wav
# Objective difference grade: -3.332. Distortion index: -1.702
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/13.wav
# Objective difference grade: -3.481. Distortion index: -2.004
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/14.wav
# Objective difference grade: -3.308. Distortion index: -1.659
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/15.wav
# Objective difference grade: -3.397. Distortion index: -1.825
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/16.wav
# Objective difference grade: -3.351. Distortion index: -1.737
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/17.wav
# Objective difference grade: -3.282. Distortion index: -1.613
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/18.wav
# Objective difference grade: -3.417. Distortion index: -1.866
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/19.wav
# Objective difference grade: -3.408. Distortion index: -1.848
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/2.wav
# Objective difference grade: -3.344. Distortion index: -1.723
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/3.wav
# Objective difference grade: -3.507. Distortion index: -2.065
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/4.wav
# Objective difference grade: -3.403. Distortion index: -1.838
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/5.wav
# Objective difference grade: -3.345. Distortion index: -1.726
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/6.wav
# Objective difference grade: -3.429. Distortion index: -1.891
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/7.wav
# Objective difference grade: -3.302. Distortion index: -1.648
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/8.wav
# Objective difference grade: -3.415. Distortion index: -1.861
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_unbiased_70_speech/9.wav
# Objective difference grade: -3.525. Distortion index: -2.108
#
#
#
#
#
#
#
#
#
# Current technique: hifigan
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/0.wav
# Objective difference grade: -3.913. Distortion index: -4.124
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/1.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/10.wav
# Objective difference grade: -3.913. Distortion index: -4.123
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/11.wav
# Objective difference grade: -3.913. Distortion index: -4.120
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/12.wav
# Objective difference grade: -3.913. Distortion index: -4.119
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/13.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/14.wav
# Objective difference grade: -3.913. Distortion index: -4.123
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/15.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/16.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/17.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/18.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/19.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/2.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/3.wav
# Objective difference grade: -3.913. Distortion index: -4.120
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/4.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/5.wav
# Objective difference grade: -3.912. Distortion index: -4.113
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/6.wav
# Objective difference grade: -3.912. Distortion index: -4.113
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/7.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/8.wav
# Objective difference grade: -3.913. Distortion index: -4.123
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/hifigan_speech/9.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
#
#
#
#
#
#
# Current technique: squeezewave
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/0.wav
# Objective difference grade: -3.913. Distortion index: -4.118
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/1.wav
# Objective difference grade: -3.911. Distortion index: -4.092
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/10.wav
# Objective difference grade: -3.912. Distortion index: -4.111
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/11.wav
# Objective difference grade: -3.912. Distortion index: -4.112
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/12.wav
# Objective difference grade: -3.911. Distortion index: -4.086
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/13.wav
# Objective difference grade: -3.912. Distortion index: -4.112
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/14.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/15.wav
# Objective difference grade: -3.912. Distortion index: -4.113
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/16.wav
# Objective difference grade: -3.912. Distortion index: -4.105
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/17.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/18.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/19.wav
# Objective difference grade: -3.912. Distortion index: -4.109
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/2.wav
# Objective difference grade: -3.912. Distortion index: -4.101
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/3.wav
# Objective difference grade: -3.912. Distortion index: -4.104
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/4.wav
# Objective difference grade: -3.912. Distortion index: -4.114
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/5.wav
# Objective difference grade: -3.911. Distortion index: -4.100
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/6.wav
# Objective difference grade: -3.910. Distortion index: -4.083
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/7.wav
# Objective difference grade: -3.912. Distortion index: -4.107
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/8.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/squeezewave_speech/9.wav
# Objective difference grade: -3.911. Distortion index: -4.099
#
#
#
#
#
#
#
# Current technique: deepgl_biased_70
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/0.wav
# Objective difference grade: -3.383. Distortion index: -1.797
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/1.wav
# Objective difference grade: -3.353. Distortion index: -1.741
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/10.wav
# Objective difference grade: -3.357. Distortion index: -1.748
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/11.wav
# Objective difference grade: -3.419. Distortion index: -1.871
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/12.wav
# Objective difference grade: -3.369. Distortion index: -1.770
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/13.wav
# Objective difference grade: -3.482. Distortion index: -2.007
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/14.wav
# Objective difference grade: -3.333. Distortion index: -1.703
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/15.wav
# Objective difference grade: -3.414. Distortion index: -1.859
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/16.wav
# Objective difference grade: -3.369. Distortion index: -1.771
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/17.wav
# Objective difference grade: -3.343. Distortion index: -1.722
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/18.wav
# Objective difference grade: -3.380. Distortion index: -1.791
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/19.wav
# Objective difference grade: -3.420. Distortion index: -1.872
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/2.wav
# Objective difference grade: -3.353. Distortion index: -1.741
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/3.wav
# Objective difference grade: -3.538. Distortion index: -2.140
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/4.wav
# Objective difference grade: -3.413. Distortion index: -1.858
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/5.wav
# Objective difference grade: -3.395. Distortion index: -1.821
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/6.wav
# Objective difference grade: -3.450. Distortion index: -1.936
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/7.wav
# Objective difference grade: -3.359. Distortion index: -1.752
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/8.wav
# Objective difference grade: -3.394. Distortion index: -1.819
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/deepgl_biased_70_speech/9.wav
# Objective difference grade: -3.465. Distortion index: -1.968
#
#
#
#
#
# Current technique: uniglow
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/0.wav
# Objective difference grade: -3.913. Distortion index: -4.123
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/1.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/10.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/11.wav
# Objective difference grade: -3.913. Distortion index: -4.118
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/12.wav
# Objective difference grade: -3.913. Distortion index: -4.117
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/13.wav
# Objective difference grade: -3.913. Distortion index: -4.121
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/14.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/15.wav
# Objective difference grade: -3.913. Distortion index: -4.118
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/16.wav
# Objective difference grade: -3.913. Distortion index: -4.120
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/17.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/18.wav
# Objective difference grade: -3.913. Distortion index: -4.120
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/19.wav
# Objective difference grade: -3.913. Distortion index: -4.122
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/signals_speech/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Speech/uniglow_speech/2.wav
# Objective difference grade: -3.913. Distortion index: -4.115
#
# ...
# Objective difference grade: -3.719. Distortion index: -2.716
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/10.wav
# Objective difference grade: -3.857. Distortion index: -3.500
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/11.wav
# Objective difference grade: -3.842. Distortion index: -3.382
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/12.wav
# Objective difference grade: -3.794. Distortion index: -3.071
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/13.wav
# Objective difference grade: -3.912. Distortion index: -4.101
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/14.wav
# Objective difference grade: -3.871. Distortion index: -3.624
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/15.wav
# Objective difference grade: -3.887. Distortion index: -3.791
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/16.wav
# Objective difference grade: -3.905. Distortion index: -4.004
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/17.wav
# Objective difference grade: -1.826. Distortion index: 0.052
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/18.wav
# Objective difference grade: -3.749. Distortion index: -2.845
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/19.wav
# Objective difference grade: -3.832. Distortion index: -3.311
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/2.wav
# Objective difference grade: -3.829. Distortion index: -3.287
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/3.wav
# Objective difference grade: -3.894. Distortion index: -3.862
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/4.wav
# Objective difference grade: -3.886. Distortion index: -3.772
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/5.wav
# Objective difference grade: -3.830. Distortion index: -3.299
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/6.wav
# Objective difference grade: -2.733. Distortion index: -0.862
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/7.wav
# Objective difference grade: -3.860. Distortion index: -3.528
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/8.wav
# Objective difference grade: -3.894. Distortion index: -3.866
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/squeezewave_urban/9.wav
# Objective difference grade: -3.891. Distortion index: -3.835
#
#
#
#
#
#
#
# Current technique: deepgl_unbiased_70
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/0.wav
# Objective difference grade: -2.754. Distortion index: -0.886
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/1.wav
# Objective difference grade: -3.298. Distortion index: -1.641
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/10.wav
# Objective difference grade: -3.644. Distortion index: -2.441
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/11.wav
# Objective difference grade: -3.162. Distortion index: -1.419
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/12.wav
# Objective difference grade: -3.233. Distortion index: -1.531
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/13.wav
# Objective difference grade: -2.835. Distortion index: -0.982
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/14.wav
# Objective difference grade: -3.425. Distortion index: -1.881
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/15.wav
# Objective difference grade: -3.703. Distortion index: -2.649
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/16.wav
# Objective difference grade: -3.009. Distortion index: -1.202
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/17.wav
# Objective difference grade: -3.330. Distortion index: -1.698
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/18.wav
# Objective difference grade: -3.262. Distortion index: -1.578
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/19.wav
# Objective difference grade: -3.252. Distortion index: -1.562
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/2.wav
# Objective difference grade: -3.316. Distortion index: -1.673
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/3.wav
# Objective difference grade: -3.646. Distortion index: -2.448
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/4.wav
# Objective difference grade: -3.625. Distortion index: -2.382
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/5.wav
# Objective difference grade: -3.629. Distortion index: -2.396
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/6.wav
# Objective difference grade: -3.286. Distortion index: -1.620
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/7.wav
# Objective difference grade: -3.275. Distortion index: -1.601
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/8.wav
# Objective difference grade: -3.684. Distortion index: -2.579
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/deepgl_unbiased_70_urban/9.wav
# Objective difference grade: -3.607. Distortion index: -2.330
#
#
#
#
#
#
#
# Current technique: griffin_lim
# Current folder: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/0.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/0.wav
# Objective difference grade: -2.206. Distortion index: -0.313
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/1.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/1.wav
# Objective difference grade: -3.034. Distortion index: -1.236
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/10.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/10.wav
# Objective difference grade: -2.845. Distortion index: -0.993
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/11.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/11.wav
# Objective difference grade: -2.980. Distortion index: -1.164
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/12.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/12.wav
# Objective difference grade: -2.836. Distortion index: -0.983
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/13.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/13.wav
# Objective difference grade: -2.431. Distortion index: -0.537
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/14.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/14.wav
# Objective difference grade: -2.779. Distortion index: -0.916
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/15.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/15.wav
# Objective difference grade: -3.098. Distortion index: -1.325
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/16.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/16.wav
# Objective difference grade: -2.865. Distortion index: -1.018
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/17.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/17.wav
# Objective difference grade: -3.064. Distortion index: -1.277
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/18.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/18.wav
# Objective difference grade: -3.148. Distortion index: -1.398
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/19.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/19.wav
# Objective difference grade: -3.144. Distortion index: -1.392
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/2.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/2.wav
# Objective difference grade: -3.310. Distortion index: -1.662
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/3.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/3.wav
# Objective difference grade: -3.070. Distortion index: -1.285
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/4.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/4.wav
# Objective difference grade: -3.096. Distortion index: -1.322
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/5.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/5.wav
# Objective difference grade: -3.136. Distortion index: -1.380
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/6.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/6.wav
# Objective difference grade: -2.954. Distortion index: -1.129
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/7.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/7.wav
# Objective difference grade: -3.172. Distortion index: -1.434
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/8.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/8.wav
# Objective difference grade: -3.044. Distortion index: -1.249
#
# Reference signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/signals_urban/9.wav
# Reconstructed signal path: /home/michele/Projects/SpectrogramPlayer/Results/Urban/griffin_lim_urban/9.wav
# Objective difference grade: -3.345. Distortion index: -1.725
